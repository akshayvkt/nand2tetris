# %%
for i in range(16):
    print(f"""
    Or(a=a[{i}],b=sel,out=int{i}{i+1});
    Or(a=b[{i}],b=notSel,out=int{i}{i+2});
    And(a=int1,b=int2,out=out[{i}]);
    """)
# Out:
#     Or(a=a[0],b=sel,out=int1);
#     Or(a=b[0],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[0]);
#
#
#     Or(a=a[1],b=sel,out=int1);
#     Or(a=b[1],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[1]);
#
#
#     Or(a=a[2],b=sel,out=int1);
#     Or(a=b[2],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[2]);
#
#
#     Or(a=a[3],b=sel,out=int1);
#     Or(a=b[3],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[3]);
#
#
#     Or(a=a[4],b=sel,out=int1);
#     Or(a=b[4],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[4]);
#
#
#     Or(a=a[5],b=sel,out=int1);
#     Or(a=b[5],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[5]);
#
#
#     Or(a=a[6],b=sel,out=int1);
#     Or(a=b[6],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[6]);
#
#
#     Or(a=a[7],b=sel,out=int1);
#     Or(a=b[7],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[7]);
#
#
#     Or(a=a[8],b=sel,out=int1);
#     Or(a=b[8],b=notSel,out=int2);
#     And(a=int1,b=int2,out=out[8]);
#
#
# ...
